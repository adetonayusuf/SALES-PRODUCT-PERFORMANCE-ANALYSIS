# %%
# Importing all necessaary libraries

import numpy as np
import pandas as pd
import matplotlib
import seaborn as sns
import warnings


import matplotlib.pyplot as plt

# %% [markdown]
# Import CSV file

# %%
superstore = pd.read_excel("superstore_sales.xlsx")

superstore.head()
# Out:
#           order_id order_date  ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040 2011-01-01 2011-01-06  Standard Class  Toby Braunhardt
# 1    IN-2011-47883 2011-01-01 2011-01-08  Standard Class      Joseph Holt
# 2     HU-2011-1220 2011-01-01 2011-01-05    Second Class    Annie Thurman
# 3  IT-2011-3647632 2011-01-01 2011-01-05    Second Class     Eugene Moren
# 4    IN-2011-47883 2011-01-01 2011-01-08  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ...  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...
# 3  Home Office        Stockholm     Sweden      EU    North  ...
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...
#
#           category sub_category                 product_name    sales  \
# ...

# %%
# Checking missing value

superstore.isnull().sum()

# %%
# Getting descriptive Statutory Summary

superstore.describe()

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# #### What's The Overall Sales Trend?

# %%
superstore['order_date'].min()
# Out:
# Timestamp('2011-01-01 00:00:00')

# %%
superstore['order_date'].max()
# Out:
# Timestamp('2014-12-31 00:00:00')

# %%
superstore['month_year'] = superstore['order_date'].apply(lambda x: x.strftime('%Y-%m'))

superstore['month_year']
# Out:
# 0        2011-01
# 1        2011-01
# 2        2011-01
# 3        2011-01
# 4        2011-01
#           ...
# 51285    2014-12
# 51286    2014-12
# 51287    2014-12
# 51288    2014-12
# 51289    2014-12
# Name: month_year, Length: 51290, dtype: object

# %%
superstore.groupby('month_year').sum()
# Out:
#                    sales  quantity  discount       profit  shipping_cost  \
# month_year
# 2011-01      98898.48886      1463    68.758   8321.80096    10544.78800
# 2011-02      91152.15698      1224    52.252  12417.90698    10681.16300
# 2011-03     145729.36736      1836    74.212  15303.56826    13096.18550
# 2011-04     116915.76418      2020    80.782  12902.32438    12954.52000
# 2011-05     146747.83610      2013    82.382  12183.82870    16443.20600
# 2011-06     215207.38022      3112   159.534  23415.24702    23813.10900
# 2011-07     115510.41912      1774    80.086   5585.00352    11844.47600
# 2011-08     207581.49122      3035   121.462  23713.66772    22001.13600
# 2011-09     290214.45534      3707   137.678  35776.88394    29664.85100
# 2011-10     199071.26404      2727   110.192  25963.41834    21380.08200
# 2011-11     298496.53752      4039   178.836  32709.17772    34701.99800
# 2011-12     333925.73460      4493   187.220  40647.98400    37144.83100
# ...

# %% [markdown]
# #### GROUPING SALES IN MONTH & YEAR

# %%
superstore.groupby('month_year').sum()['sales']
# Out:
# month_year
# 2011-01     98898.48886
# 2011-02     91152.15698
# 2011-03    145729.36736
# 2011-04    116915.76418
# 2011-05    146747.83610
# 2011-06    215207.38022
# 2011-07    115510.41912
# 2011-08    207581.49122
# 2011-09    290214.45534
# 2011-10    199071.26404
# 2011-11    298496.53752
# 2011-12    333925.73460
# 2012-01    135780.72024
# 2012-02    100510.21698
# 2012-03    163076.77116
# 2012-04    161052.26952
# 2012-05    208364.89124
# 2012-06    256175.69842
# 2012-07    145236.78512
# 2012-08    303142.94238
# 2012-09    289389.16564
# 2012-10    252939.85020
# 2012-11    323512.41690
# 2012-12    338256.96660
# 2013-01    199185.90738
# 2013-02    167239.65040
# 2013-03    198594.03012
# 2013-04    177821.31684
# 2013-05    260498.56470
# 2013-06    396519.61190
# 2013-07    229928.95200
# 2013-08    326488.78936
# 2013-09    376619.24568
# 2013-10    293406.64288
# 2013-11    373989.36010
# 2013-12    405454.37802
# 2014-01    241268.55566
# ...

# %%
superstore.groupby('month_year').sum()['sales'].reset_index()
# Out:
#    month_year         sales
# 0     2011-01   98898.48886
# 1     2011-02   91152.15698
# 2     2011-03  145729.36736
# 3     2011-04  116915.76418
# 4     2011-05  146747.83610
# 5     2011-06  215207.38022
# 6     2011-07  115510.41912
# 7     2011-08  207581.49122
# 8     2011-09  290214.45534
# 9     2011-10  199071.26404
# 10    2011-11  298496.53752
# 11    2011-12  333925.73460
# 12    2012-01  135780.72024
# 13    2012-02  100510.21698
# 14    2012-03  163076.77116
# 15    2012-04  161052.26952
# 16    2012-05  208364.89124
# 17    2012-06  256175.69842
# 18    2012-07  145236.78512
# 19    2012-08  303142.94238
# 20    2012-09  289389.16564
# 21    2012-10  252939.85020
# 22    2012-11  323512.41690
# 23    2012-12  338256.96660
# 24    2013-01  199185.90738
# 25    2013-02  167239.65040
# 26    2013-03  198594.03012
# 27    2013-04  177821.31684
# 28    2013-05  260498.56470
# 29    2013-06  396519.61190
# 30    2013-07  229928.95200
# 31    2013-08  326488.78936
# ...

# %% [markdown]
# #### VISUALIZING SALES TREND

# %%
sales_trend = superstore.groupby('month_year').sum()['sales'].reset_index()

# %%
plt.figure(figsize=(15,6))

plt.plot(sales_trend['month_year'], sales_trend['sales'])
plt.xticks(rotation='vertical', size=8)
plt.show()

# %% [markdown]
# The above line charts indicates that the company's peak period is between Nov-Dec while the least performing periods are Jan-Feb

# %% [markdown]
# ### Which are the top 10 products by sale?

# %%
superstore.groupby('product_name').sum()
# Out:
#                                                        sales  quantity  \
# product_name
# "While you Were Out" Message Book, One Form per...    25.228         8
# #10 Gummed Flap White Envelopes, 100/Box              41.300        11
# #10 Self-Seal White Envelopes                        108.682        10
# #10 White Business Envelopes,4 1/8 x 9 1/2           488.904        32
# #10- 4 1/8" x 9 1/2" Recycled Envelopes              286.672        37
# ...                                                      ...       ...
# iKross Bluetooth Portable Keyboard + Cell Phone...   477.660        24
# iOttie HLCRIO102 Car Mount                           215.892        12
# iOttie XL Car Mount                                  223.888        14
# invisibleSHIELD by ZAGG Smudge-Free Screen Prot...   442.554        29
# netTALK DUO VoIP Telephone Service                  1112.788        26
#
#                                                     discount    profit  \
# product_name
# ...

# %%
superstore.groupby('product_name').sum()['sales']
# Out:
# product_name
# "While you Were Out" Message Book, One Form per Page                                                     25.228
# #10 Gummed Flap White Envelopes, 100/Box                                                                 41.300
# #10 Self-Seal White Envelopes                                                                           108.682
# #10 White Business Envelopes,4 1/8 x 9 1/2                                                              488.904
# #10- 4 1/8" x 9 1/2" Recycled Envelopes                                                                 286.672
#                                                                                                          ...
# iKross Bluetooth Portable Keyboard + Cell Phone Stand Holder + Brush for Apple iPhone 5S 5C 5, 4S 4     477.660
# iOttie HLCRIO102 Car Mount                                                                              215.892
# ...

# %%
pd.DataFrame(superstore.groupby('product_name').sum()['sales'])
# Out:
#                                                        sales
# product_name
# "While you Were Out" Message Book, One Form per...    25.228
# #10 Gummed Flap White Envelopes, 100/Box              41.300
# #10 Self-Seal White Envelopes                        108.682
# #10 White Business Envelopes,4 1/8 x 9 1/2           488.904
# #10- 4 1/8" x 9 1/2" Recycled Envelopes              286.672
# ...                                                      ...
# iKross Bluetooth Portable Keyboard + Cell Phone...   477.660
# iOttie HLCRIO102 Car Mount                           215.892
# iOttie XL Car Mount                                  223.888
# invisibleSHIELD by ZAGG Smudge-Free Screen Prot...   442.554
# netTALK DUO VoIP Telephone Service                  1112.788
#
# [3788 rows x 1 columns]

# %%
product_sale = pd.DataFrame(superstore.groupby('product_name').sum()['sales'])

# %%
product_sale.sort_values('sales', ascending=False)
# Out:
#                                                          sales
# product_name
# Apple Smart Phone, Full Size                        86935.7786
# Cisco Smart Phone, Full Size                        76441.5306
# Motorola Smart Phone, Full Size                     73156.3030
# Nokia Smart Phone, Full Size                        71904.5555
# Canon imageCLASS 2200 Advanced Copier               61599.8240
# ...                                                        ...
# Avery Hi-Liter Pen Style Six-Color Fluorescent Set      7.7000
# Grip Seal Envelopes                                     7.0720
# Xerox 20                                                6.4800
# Avery 5                                                 5.7600
# Eureka Disposable Bags for Sanitaire Vibra Groo...      1.6240
#
# [3788 rows x 1 columns]

# %%
product_sale = product_sale.sort_values('sales', ascending=False)

# %%
product_sale[:10]
# Out:
#                                                          sales
# product_name
# Apple Smart Phone, Full Size                        86935.7786
# Cisco Smart Phone, Full Size                        76441.5306
# Motorola Smart Phone, Full Size                     73156.3030
# Nokia Smart Phone, Full Size                        71904.5555
# Canon imageCLASS 2200 Advanced Copier               61599.8240
# Hon Executive Leather Armchair, Adjustable          58193.4841
# Office Star Executive Leather Armchair, Adjustable  50661.6840
# Harbour Creations Executive Leather Armchair, A...  50121.5160
# Samsung Smart Phone, Cordless                       48653.4600
# Nokia Smart Phone, with Caller ID                   47877.7857

# %% [markdown]
# The above table shows best 10 performing products in the store. The best performing product is Apple Smart Phone follows by Cisco smart phone

# %%
superstore.groupby('product_name').sum()
# Out:
#                                                        sales  quantity  \
# product_name
# "While you Were Out" Message Book, One Form per...    25.228         8
# #10 Gummed Flap White Envelopes, 100/Box              41.300        11
# #10 Self-Seal White Envelopes                        108.682        10
# #10 White Business Envelopes,4 1/8 x 9 1/2           488.904        32
# #10- 4 1/8" x 9 1/2" Recycled Envelopes              286.672        37
# ...                                                      ...       ...
# iKross Bluetooth Portable Keyboard + Cell Phone...   477.660        24
# iOttie HLCRIO102 Car Mount                           215.892        12
# iOttie XL Car Mount                                  223.888        14
# invisibleSHIELD by ZAGG Smudge-Free Screen Prot...   442.554        29
# netTALK DUO VoIP Telephone Service                  1112.788        26
#
#                                                     discount    profit  \
# product_name
# ...

# %%
pd.DataFrame(superstore.groupby('product_name').sum()['quantity'])
# Out:
#                                                     quantity
# product_name
# "While you Were Out" Message Book, One Form per...         8
# #10 Gummed Flap White Envelopes, 100/Box                  11
# #10 Self-Seal White Envelopes                             10
# #10 White Business Envelopes,4 1/8 x 9 1/2                32
# #10- 4 1/8" x 9 1/2" Recycled Envelopes                   37
# ...                                                      ...
# iKross Bluetooth Portable Keyboard + Cell Phone...        24
# iOttie HLCRIO102 Car Mount                                12
# iOttie XL Car Mount                                       14
# invisibleSHIELD by ZAGG Smudge-Free Screen Prot...        29
# netTALK DUO VoIP Telephone Service                        26
#
# [3788 rows x 1 columns]

# %%
Most_Sold_Product = pd.DataFrame(superstore.groupby('product_name').sum()['quantity'])

# %%
Most_Sold_Product.sort_values('quantity', ascending=False)
# Out:
#                                                     quantity
# product_name
# Staples                                                  876
# Cardinal Index Tab, Clear                                337
# Eldon File Cart, Single Width                            321
# Rogers File Cart, Single Width                           262
# Sanford Pencil Sharpener, Water Color                    259
# ...                                                      ...
# Penpower WorldCard Pro Card Scanner                        1
# Bush Saratoga Collection 5-Shelf Bookcase, Hano...         1
# Boston 1900 Electric Pencil Sharpener                      1
# Xerox 20                                                   1
# Global Enterprise Series Seating Low-Back Swive...         1
#
# [3788 rows x 1 columns]

# %%
Most_Sold_Product = Most_Sold_Product.sort_values('quantity', ascending=False)

# %%
Most_Sold_Product[:10]
# Out:
#                                        quantity
# product_name
# Staples                                     876
# Cardinal Index Tab, Clear                   337
# Eldon File Cart, Single Width               321
# Rogers File Cart, Single Width              262
# Sanford Pencil Sharpener, Water Color       259
# Stockwell Paper Clips, Assorted Sizes       253
# Avery Index Tab, Clear                      252
# Ibico Index Tab, Clear                      251
# Smead File Cart, Single Width               250
# Stanley Pencil Sharpener, Water Color       242

# %%
The top 10 products sold are shown above, the best performing product in terms of unit sold 'Staples'

# %% [markdown]
# #### What is the most preferred ship move

# %%
plt.figure(figsize=(10,8.5))

sns.countplot(superstore['ship_mode'])

plt.show()
# Out:
# C:\Users\YUSUF\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# The most preferable means of shipping by customers is 'Standard Class'

# %% [markdown]
# #### Which are the most profitable category and sub-category

# %%
superstore.groupby(['category', 'sub_category']).sum()
# Out:
#                                      sales  quantity  discount        profit  \
# category        sub_category
# Furniture       Bookcases     1.466572e+06      8310   370.710  161924.41950
#                 Chairs        1.501682e+06     12336   560.120  141973.79750
#                 Furnishings   3.855783e+05     11225   478.880   46967.42550
#                 Tables        7.570419e+05      3083   250.320  -64083.38870
# Office Supplies Appliances    1.011064e+06      6078   248.700  141680.58940
#                 Art           3.720920e+05     16301   573.080   57953.91090
#                 Binders       4.619115e+05     21429  1102.480   72449.84600
#                 Envelopes     1.709043e+05      8380   320.810   29601.11630
#                 Fasteners     8.324232e+04      8390   340.240   11525.42410
#                 Labels        7.340403e+04      9322   313.890   15010.51200
#                 Paper         2.442917e+05     12822   387.300   59207.68270
# ...

# %%
pd.DataFrame(superstore.groupby(['category', 'sub_category']).sum()['profit'])
# Out:
#                                     profit
# category        sub_category
# Furniture       Bookcases     161924.41950
#                 Chairs        141973.79750
#                 Furnishings    46967.42550
#                 Tables        -64083.38870
# Office Supplies Appliances    141680.58940
#                 Art            57953.91090
#                 Binders        72449.84600
#                 Envelopes      29601.11630
#                 Fasteners      11525.42410
#                 Labels         15010.51200
#                 Paper          59207.68270
#                 Storage       108461.48980
#                 Supplies       22583.26310
# Technology      Accessories   129626.30620
#                 Copiers       258567.54818
#                 Machines       58867.87300
#                 Phones        216717.00580

# %%
Category_Sub_Category_Profit = pd.DataFrame(superstore.groupby(['category', 'sub_category']).sum()['profit'])

# %%
Category_Sub_Category_Profit.sort_values(['category', 'profit'], ascending=False)
# Out:
#                                     profit
# category        sub_category
# Technology      Copiers       258567.54818
#                 Phones        216717.00580
#                 Accessories   129626.30620
#                 Machines       58867.87300
# Office Supplies Appliances    141680.58940
#                 Storage       108461.48980
#                 Binders        72449.84600
#                 Paper          59207.68270
#                 Art            57953.91090
#                 Envelopes      29601.11630
#                 Supplies       22583.26310
#                 Labels         15010.51200
#                 Fasteners      11525.42410
# Furniture       Bookcases     161924.41950
#                 Chairs        141973.79750
#                 Furnishings    46967.42550
#                 Tables        -64083.38870

# %% [markdown]
# The best selling category is Technology along with the sub-category under it

# %% [markdown]
# #### The most profitable region

# %%
superstore.groupby(['region']).sum()
# Out:
#                        sales  quantity  discount        profit  shipping_cost  \
# region
# Africa          7.837732e+05     10564   718.800   88871.63100     88139.4700
# Canada          6.692817e+04       833     0.000   17817.39000      7405.6300
# Caribbean       3.242809e+05      6299   229.420   34571.32104     35589.3760
# Central         2.822303e+06     41762  1543.610  311403.98164    296939.1000
# Central Asia    7.528266e+05      7715   138.200  132480.18700     77830.1500
# EMEA            8.061613e+05     11517   986.100   43897.97100     88375.7300
# East            6.787812e+05     10618   414.000   91522.78000     72743.6200
# North           1.248166e+06     18021   459.630  194597.95252    131472.6480
# North Asia      8.483098e+05      8851   113.900  165578.42100     95030.6100
# Oceania         1.100185e+06     12838   534.100  121666.64200    120628.5100
# South           1.600907e+06     25206   990.438  140355.76618    168472.7515
# ...

# %%
Region_Performance = pd.DataFrame(superstore.groupby('region').sum()['profit'])

# %%
Region_Performance.sort_values(['profit'], ascending=False)
# Out:
#                       profit
# region
# Central         311403.98164
# North           194597.95252
# North Asia      165578.42100
# South           140355.76618
# Central Asia    132480.18700
# Oceania         121666.64200
# West            108418.44890
# East             91522.78000
# Africa           88871.63100
# EMEA             43897.97100
# Caribbean        34571.32104
# Southeast Asia   17852.32900
# Canada           17817.39000

# %% [markdown]
# The most profitable region is 'Central'

# %% [markdown]
# #### The most profitable country?

# %%
superstore.groupby(['country']).sum()
# Out:
#                    sales  quantity  discount       profit  shipping_cost  \
# country
# Afghanistan  21673.32000       228     0.000   5460.30000       2300.230
# Albania       3888.12000        40     0.000    709.32000        698.570
# Algeria      36091.59000       454     0.000   9106.50000       3726.410
# Angola       25554.00000       317     0.000   6494.97000       2418.400
# Argentina    57511.78328      1504   168.952 -18693.79672       6366.362
# ...                  ...       ...       ...          ...            ...
# Venezuela    26587.82956       774    79.426 -11222.71044       2809.961
# Vietnam      65800.19940       996    63.450  -1870.23060       7684.370
# Yemen         2465.71200        71    21.000  -3706.45800        286.630
# Zambia       26035.50000       251     0.000   7001.73000       3067.200
# Zimbabwe      3765.10500       190    56.000  -5428.78500        476.220
#
#                year
# country
# Afghanistan  110701
# Albania       32196
# ...

# %%
Country_Performance = pd.DataFrame(superstore.groupby('country').sum()['profit'])

# %%
Country_Performance.sort_values(['profit'], ascending=False)
# Out:
#                      profit
# country
# United States   286397.0217
# China           150683.0850
# India           129071.8350
# United Kingdom  111900.1500
# France          109029.0030
# ...                     ...
# Pakistan        -22446.6480
# Honduras        -29482.3714
# Netherlands     -41070.0750
# Nigeria         -80750.7180
# Turkey          -98447.2320
#
# [147 rows x 1 columns]

# %% [markdown]
# The company made the most profit in 'United State'

# %% [markdown]
# #### Products that are sold together

# %%
# Products that are sold together

Products_Sold_Together = superstore[superstore['order_id'].duplicated(keep=False)]

Products_Sold_Together
# Out:
#              order_id order_date  ship_date       ship_mode     customer_name  \
# 1       IN-2011-47883 2011-01-01 2011-01-08  Standard Class       Joseph Holt
# 4       IN-2011-47883 2011-01-01 2011-01-08  Standard Class       Joseph Holt
# 5       IN-2011-47883 2011-01-01 2011-01-08  Standard Class       Joseph Holt
# 7       IN-2011-79397 2011-01-03 2011-01-03        Same Day       Kean Nguyen
# 8       ID-2011-80230 2011-01-03 2011-01-09  Standard Class      Ken Lonsdale
# ...               ...        ...        ...             ...               ...
# 51281  CA-2014-115427 2014-12-31 2015-01-04  Standard Class        Erica Bern
# 51283   IN-2014-23754 2014-12-31 2015-01-07  Standard Class      Kalyca Meade
# 51285  CA-2014-115427 2014-12-31 2015-01-04  Standard Class        Erica Bern
# 51287  MX-2014-110527 2014-12-31 2015-01-02    Second Class  Charlotte Melton
# 51288  MX-2014-114783 2014-12-31 2015-01-06  Standard Class     Tamara Dahlen
#
# ...

# %%
Products_Sold_Together = superstore[superstore['order_id'].duplicated(keep=False)]

Products_Sold_Together['Grouped'] = superstore.groupby('order_id')['product_name'].transform(lambda x: ','.join(x))

Products_Sold_Together.head()
# Out:
# <ipython-input-33-40051efea416>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Products_Sold_Together['Grouped'] = superstore.groupby('order_id')['product_name'].transform(lambda x: ','.join(x))
#         order_id order_date  ship_date       ship_mode customer_name  \
# 1  IN-2011-47883 2011-01-01 2011-01-08  Standard Class   Joseph Holt
# 4  IN-2011-47883 2011-01-01 2011-01-08  Standard Class   Joseph Holt
# 5  IN-2011-47883 2011-01-01 2011-01-08  Standard Class   Joseph Holt
# 7  IN-2011-79397 2011-01-03 2011-01-03        Same Day   Kean Nguyen
# 8  ID-2011-80230 2011-01-03 2011-01-09  Standard Class  Ken Lonsdale
#
#      segment            state      country market   region  ... sub_category  \
# ...

# %%
Products_Sold_Together = superstore[superstore['order_id'].duplicated(keep=False)]

Products_Sold_Together['Grouped'] = superstore.groupby('order_id')['product_name'].transform(lambda x: ','.join(x))

Products_Sold_Together = Products_Sold_Together[['order_id', 'Grouped']].drop_duplicates()

Products_Sold_Together.head()
# Out:
# <ipython-input-39-b2129397ca6c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Products_Sold_Together['Grouped'] = superstore.groupby('order_id')['product_name'].transform(lambda x: ','.join(x))
#          order_id                                            Grouped
# 1   IN-2011-47883  Acme Trimmer, High Speed,Eldon Light Bulb, Duo...
# 7   IN-2011-79397  Hoover Microwave, White,Avery Color Coded Labe...
# 8   ID-2011-80230  Hewlett Wireless Fax, Laser,Hon Rocking Chair,...
# 9    IZ-2011-4680  Novimex Swivel Stool, Set of Two,Cameo Interof...
# 10  IN-2011-65159  Tenex Lockers, Industrial,Chromcraft Round Tab...

# %%
from itertools import combinations
from collections import Counter

count = Counter()

for row in Products_Sold_Together['Grouped']:
    row_list = row.split(',')
    count.update(Counter(combinations(row_list, 2)))

for key, value in count.most_common(10):
    print(key, value)

# Common 2
# Out:
# (' Blue', ' Recycled') 156
# (' Black', ' Recycled') 132
# (' Red', ' Durable') 124
# (' Red', ' Recycled') 123
# (' Blue', ' Blue') 122
# (' Recycled', ' Recycled') 121
# (' Durable', ' Durable') 120
# (' Durable', ' Recycled') 115
# (' Black', ' Durable') 110
# (' Blue', ' Clear') 109

# %% [markdown]
# These are the most 2 products sold together. It'll be advisable to advertise them together, in order to generate more income from them.

# %%
count = Counter()

for row in Products_Sold_Together['Grouped']:
    row_list = row.split(',')
    count.update(Counter(combinations(row_list, 3)))

for key, value in count.most_common(10):
    print(key, value)

# Common 3
# Out:
# (' Durable', 'Cardinal Index Tab', ' Clear') 16
# (' Traditional', ' Recycled', ' Recycled') 15
# (' Erganomic', ' Blue', ' Economy') 14
# (' Traditional', ' Blue', ' Recycled') 14
# (' Blue', 'Ibico Index Tab', ' Clear') 13
# (' Blue', ' Blue', ' Clear') 13
# (' Blue', ' Clear', ' Recycled') 13
# (' Blue', ' Economy', ' Clear') 13
# (' Red', ' Durable', ' Recycled') 12
# (' Durable', ' Recycled', ' Recycled') 12

# %% [markdown]
# These are the most 3 products sold together. It'll be advisable to advertise them together, in order to generate more income from them if possible.

# %%
count = Counter()

for row in Products_Sold_Together['Grouped']:
    row_list = row.split(',')
    count.update(Counter(combinations(row_list, 4)))

for key, value in count.most_common(10):
    print(key, value)

# Common 4
# Out:
# ('Wilson Jones Ledger-Size', ' Piano-Hinge Binder', ' 2"', ' Blue') 11
# ('GBC Prepunched Paper', ' 19-Hole', ' for Binding Systems', ' 24-lb') 10
# ('HP Fax and Copier', ' Digital', ' Durable', ' Recycled') 7
# ('Rubbermaid Frame', ' Erganomic', ' Recycled', ' Recycled') 7
# ('Hon Executive Leather Armchair', ' Adjustable', 'Novimex Rocking Chair', ' Durable') 7
# (' Erganomic', ' Single Width', 'Tenex Box', ' Wire Frame') 6
# ('GBC Pre-Punched Binding Paper', ' Plastic', ' White', ' 8-1/2" x 11"') 6
# ('Lesro Sheffield Collection Coffee Table', ' End Table', ' Center Table', ' Corner Table') 6
# ('Tennsco Stur-D-Stor Boltless Shelving', ' 5 Shelves', ' 24" Deep', ' Sand') 6
# ('GE 48" Fluorescent Tube', ' Cool White Energy Saver', ' 34 Watts', ' 30/Box') 6

# %%
These are the most 4 products sold together. It'll be advisable to advertise them together, in order to generate more income from them if possible.

# %%
# The most profitable segment

superstore.groupby(['segment']).sum()

#At a glance the segment with the most activities and perfomance is 'Customer'
# Out:
#                     sales  quantity  discount        profit  shipping_cost  \
# segment
# Consumer     6.507949e+06     92157  3808.042  749239.78206    697298.1199
# Corporate    3.824698e+06     53565  2205.284  442785.85866    410472.9120
# Home Office  2.309855e+06     32590  1316.402  277009.18056    245044.6715
#
#                  year
# segment
# Consumer     53374470
# Corporate    31055044
# Home Office  18805829

# %% [markdown]
# The best performing segment is 'Customer' in terms of revenue and profit. The company should invest more in the segment to generate more revenue.
